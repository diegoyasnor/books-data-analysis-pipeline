# %% [markdown]
# # Books Data Analysis Pipeline
#
# This project demonstrates an end-to-end data analysis workflow, from web scraping
# to data cleaning, exploratory analysis, and experimental design.
#
# The objective is to showcase core data analyst skills such as data extraction,
# data quality validation, exploratory analysis, and data-driven decision-making.
#
# ---
#
# ## Project Overview
#
# - Scraped a public book catalog website using Python
# - Built a reproducible data extraction pipeline
# - Cleaned and standardized raw data using pandas
# - Performed exploratory data analysis (EDA)
# - Designed and analyzed a simulated A/B test to support decision-making
#
# ---
#
# ## Data Extraction
#
# Initial HTML exploration was performed in a Jupyter notebook to validate CSS selectors.
# Final data extraction was implemented as a standalone Python script to ensure
# reproducibility and scalability.
#
# - Script: `src/extract/scrape_all_pages.py`
# - Output: `data/raw/books_raw.csv`
#
# ---
#
# ## Data Cleaning
#
# Raw data was cleaned and standardized using pandas:
# - Converted categorical ratings to numerical values
# - Validated data types and missing values
# - Engineered basic features for analysis and experimentation
#
# - Notebook: `notebooks/01_cleaning.ipynb`
# - Output: `data/processed/books_clean.csv`
#
# ---
#
# ## Exploratory Data Analysis (EDA)
#
# Exploratory analysis focused on pricing and rating patterns:
# - Price distribution analysis
# - Rating vs price comparison
# - Identification of data limitations and next steps
#
# - Notebook: `notebooks/02_eda.ipynb`
#
# ---
#
# ## A/B Testing (Simulated)
#
# A simulated A/B test was implemented to evaluate whether highlighting
# highly-rated books could increase conversion rates.
#
# Since real user-level conversion data was not available, conversion outcomes
# were simulated to demonstrate experimental design and statistical reasoning.
#
# - Hypothesis formulation
# - Random assignment to control and variant groups
# - Conversion rate comparison
# - Statistical significance testing
#
# - Notebook: `notebooks/03_ab_testing.ipynb`
#
# ---
#
# ## Key Takeaways
#
# - Book prices are not evenly distributed and cluster around a mid-price range
# - Rating alone does not fully explain pricing differences
# - The simulated A/B test did not show statistically significant results,
#   highlighting the importance of data-driven validation before making decisions
#
# ---
#
# ## Future Improvements
#
# - Scrape category and product description data from individual product pages
# - Incorporate text-based features using basic NLP techniques
# - Extend experimentation with larger samples or alternative treatments
#
# ---
#
# ## Tools Used
#
# - Python
# - pandas
# - NumPy
# - BeautifulSoup
# - requests
# - matplotlib
# - scipy
